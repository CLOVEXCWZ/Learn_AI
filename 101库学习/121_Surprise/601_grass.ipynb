# %% [markdown]
# # 基本使用方法
#
# [原博客地址](https://blog.csdn.net/qq_26877377/article/details/79980107)

# %%
from surprise import SVD
from surprise import Dataset
from surprise import evaluate, print_perf

import os

# %%
path = '/Users/zhouwencheng/Desktop/Grass/05 AI/201AI/1base/220 Surprise(Python推荐系统库)/data/u.data.txt' # 指定文件所在路径 
file_path = os.path.expanduser(path) 
reader = Reader(line_format='user item rating timestamp', sep='\t') # 告诉文本阅读器，文本的格式是怎么样的
data = Dataset.load_from_file(file_path, reader=reader) # 加载数据
# 手动切分成5折(方便交叉验证)
data.split(n_folds=3) 
# SVD
algo = SVD()
# 看效果
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])
# 输出结果
print_perf(pref)
# Out:
# /Users/zhouwencheng/anaconda3/lib/python3.7/site-packages/surprise/evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# /Users/zhouwencheng/anaconda3/lib/python3.7/site-packages/surprise/dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9464
# MAE:  0.7481
# ------------
# Fold 2
# RMSE: 0.9489
# MAE:  0.7487
# ------------
# Fold 3
# RMSE: 0.9433
# MAE:  0.7453
# ------------
# ------------
# Mean RMSE: 0.9462
# Mean MAE : 0.7474
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9464  0.9489  0.9433  0.9462
# MAE     0.7481  0.7487  0.7453  0.7474

# %% [markdown]
# # 算法调参

# %%
from surprise.model_selection import GridSearchCV
from surprise import SVD
import os
from surprise import Dataset

param_grid = {'n_epochs':[5, 10], 'lr_all':[0.002, 0.005], 'reg_all':[0.4, 0.6]}

grid_search = GridSearchCV(SVD, param_grid, measures=['RMSE', 'FCP'])
path = '/Users/zhouwencheng/Desktop/Grass/05 AI/201AI/1base/220 Surprise(Python推荐系统库)/data/u.data.txt' # 指定文件所在路径 
file_path = os.path.expanduser(path) 
reader = Reader(line_format='user item rating timestamp', sep='\t') # 告诉文本阅读器，文本的格式是怎么样的
data = Dataset.load_from_file(file_path, reader=reader) # 加载数据

data.split(n_folds = 3)
# grid_search.evaluate(data)
grid_search.fit(data)

# %%
# 输出调优的参数组 
# 输出最好的RMSE结果
print(grid_search.best_score['rmse']) 
# # 输出对应最好的RMSE结果的参数
print('best params of R:', grid_search.best_params['rmse']) 
# 最好的FCP得分
print('best score of FCP:', grid_search.best_score['fcp']) 
# 对应最高FCP得分的参数'
print('best params of FCP:', grid_search.best_params['fcp'])
# Out:
# 0.9611622145892567
# best params of R: {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}
# best score of FCP: 0.6928636206568304
# best params of FCP: {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %%
import os
from surprise import Dataset

path = '/Users/zhouwencheng/Desktop/Grass/05 AI/201AI/1base/220 Surprise(Python推荐系统库)/data/u.data.txt' # 指定文件所在路径 
file_path = os.path.expanduser(path) 
reader = Reader(line_format='user item rating timestamp', sep='\t') # 告诉文本阅读器，文本的格式是怎么样的
data = Dataset.load_from_file(file_path, reader=reader) # 加载数据
data.split(n_folds=2)

from surprise import NormalPredictor, evaluate
algo = NormalPredictor()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import BaselineOnly, evaluate
algo = BaselineOnly()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import KNNBasic, evaluate
algo = KNNBasic()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import KNNWithMeans, evaluate
algo = KNNWithMeans()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import KNNBaseline, evaluate
algo = KNNBaseline()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import SVD, evaluate
algo = SVD()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import SVDpp, evaluate
algo = SVDpp()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])

from surprise import NMF, evaluate
algo = NMF()
pref = evaluate(algo, data, measures=['RMSE', 'MAE'])
# Out:
# /Users/zhouwencheng/anaconda3/lib/python3.7/site-packages/surprise/evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# /Users/zhouwencheng/anaconda3/lib/python3.7/site-packages/surprise/dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm NormalPredictor.
#
# ------------
# Fold 1
# RMSE: 1.5181
# MAE:  1.2185
# ------------
# Fold 2
# RMSE: 1.5164
# MAE:  1.2188
# ------------
# ------------
# Mean RMSE: 1.5173
# Mean MAE : 1.2186
# ------------
# ------------
# Evaluating RMSE, MAE of algorithm BaselineOnly.
#
# ------------
# Fold 1
# Estimating biases using als...
# RMSE: 0.9516
# MAE:  0.7561
# ------------
# Fold 2
# Estimating biases using als...
# RMSE: 0.9531
# MAE:  0.7569
# ------------
# ------------
# Mean RMSE: 0.9524
# ...
