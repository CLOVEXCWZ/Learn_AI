# %%
#coding=utf-8
from keras.models import Model
from keras.layers import Input,Dense,Dropout,BatchNormalization,Conv2D,MaxPooling2D,AveragePooling2D,concatenate,Activation,ZeroPadding2D
from keras.layers import add,Flatten
import numpy as np
seed = 7
np.random.seed(seed)

# %%
num_BN = 1

def Conv2d_BN(x, nb_filter,kernel_size, strides=(1,1), padding='same',name=None):
    if name is None:
        name = str(num_BN)
        num_BN += 1 
    conv_name = name + "_Conv"  
    bn_name = name + "_BN"
    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides,activation='relu',name=conv_name)(x)
    x = BatchNormalization(axis=3,name=bn_name)(x)
    return x

def Conv_Block(inpt,nb_filter,kernel_size,strides=(1,1), with_conv_shortcut=False, block_no=None):
    block_name = "block"+str(block_no)
    x = Conv2d_BN(inpt,nb_filter=nb_filter,kernel_size=kernel_size,strides=strides,padding='same', name=block_name+"_1")
    x = Conv2d_BN(x, nb_filter=nb_filter, kernel_size=kernel_size,padding='same',  name=block_name+"_2")
    if with_conv_shortcut:
        shortcut = Conv2d_BN(inpt,nb_filter=nb_filter,strides=strides,kernel_size=kernel_size, name="short_block"+str(block_no))
        x = add([x,shortcut])
        return x
    else:
        x = add([x,inpt])
        return x

# %%
inpt = Input(shape=(224,224,3), name="Input")
x = ZeroPadding2D((3,3), name="ZeroPadding")(inpt)
x = Conv2d_BN(x,nb_filter=64,kernel_size=(7,7),strides=(2,2),padding='valid', name="NB1") 
x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same', name="pool1")(x)
#(56,56,64)
x = Conv_Block(x,nb_filter=64,kernel_size=(3,3), block_no=1)
x = Conv_Block(x,nb_filter=64,kernel_size=(3,3), block_no=2)
x = Conv_Block(x,nb_filter=64,kernel_size=(3,3), block_no=3)
#(28,28,128)
x = Conv_Block(x,nb_filter=128,kernel_size=(3,3),strides=(2,2),with_conv_shortcut=True, block_no=4)
x = Conv_Block(x,nb_filter=128,kernel_size=(3,3), block_no=5)
x = Conv_Block(x,nb_filter=128,kernel_size=(3,3), block_no=6)
x = Conv_Block(x,nb_filter=128,kernel_size=(3,3), block_no=7)
#(14,14,256)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3),strides=(2,2),with_conv_shortcut=True, block_no=8)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3), block_no=9)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3), block_no=10)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3), block_no=11)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3), block_no=12)
x = Conv_Block(x,nb_filter=256,kernel_size=(3,3), block_no=13)
#(7,7,512)
x = Conv_Block(x,nb_filter=512,kernel_size=(3,3),strides=(2,2),with_conv_shortcut=True, block_no=14)
x = Conv_Block(x,nb_filter=512,kernel_size=(3,3), block_no=15)
x = Conv_Block(x,nb_filter=512,kernel_size=(3,3), block_no=16)
x = AveragePooling2D(pool_size=(7,7), name="AveragePooling2D1")(x)
x = Flatten(name="Flat1")(x)
x = Dense(1000,activation='softmax', name="Dense1")(x)
 
model = Model(inputs=inpt,outputs=x)
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
model.summary()

# 把模型保存为图片
from keras.utils import plot_model
plot_model(model,to_file='model_png/206Resnet34.png', show_layer_names=True, show_shapes=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0808 17:07:47.029598 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0808 17:07:47.081192 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0808 17:07:47.159668 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0808 17:07:47.161434 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0808 17:07:47.163357 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0808 17:07:47.219631 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0808 17:07:47.371403 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0808 17:07:54.231739 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# W0808 17:07:54.292372 4321588096 deprecation_wrapper.py:119] From /Users/zhouwencheng/Desktop/Grass/02Study/02PythonEnv/envpy3.7/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# ZeroPadding (ZeroPadding2D)     (None, 230, 230, 3)  0           Input[0][0]
# __________________________________________________________________________________________________
# NB1_Conv (Conv2D)               (None, 112, 112, 64) 9472        ZeroPadding[0][0]
# __________________________________________________________________________________________________
# NB1_BN (BatchNormalization)     (None, 112, 112, 64) 256         NB1_Conv[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           NB1_BN[0][0]
# __________________________________________________________________________________________________
# block1_1_Conv (Conv2D)          (None, 56, 56, 64)   36928       pool1[0][0]
# __________________________________________________________________________________________________
# block1_1_BN (BatchNormalization (None, 56, 56, 64)   256         block1_1_Conv[0][0]
# __________________________________________________________________________________________________
# block1_2_Conv (Conv2D)          (None, 56, 56, 64)   36928       block1_1_BN[0][0]
# __________________________________________________________________________________________________
# block1_2_BN (BatchNormalization (None, 56, 56, 64)   256         block1_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           block1_2_BN[0][0]
#                                                                  pool1[0][0]
# __________________________________________________________________________________________________
# block2_1_Conv (Conv2D)          (None, 56, 56, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# block2_1_BN (BatchNormalization (None, 56, 56, 64)   256         block2_1_Conv[0][0]
# __________________________________________________________________________________________________
# block2_2_Conv (Conv2D)          (None, 56, 56, 64)   36928       block2_1_BN[0][0]
# __________________________________________________________________________________________________
# block2_2_BN (BatchNormalization (None, 56, 56, 64)   256         block2_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 64)   0           block2_2_BN[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# block3_1_Conv (Conv2D)          (None, 56, 56, 64)   36928       add_2[0][0]
# __________________________________________________________________________________________________
# block3_1_BN (BatchNormalization (None, 56, 56, 64)   256         block3_1_Conv[0][0]
# __________________________________________________________________________________________________
# block3_2_Conv (Conv2D)          (None, 56, 56, 64)   36928       block3_1_BN[0][0]
# __________________________________________________________________________________________________
# block3_2_BN (BatchNormalization (None, 56, 56, 64)   256         block3_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 64)   0           block3_2_BN[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block4_1_Conv (Conv2D)          (None, 28, 28, 128)  73856       add_3[0][0]
# __________________________________________________________________________________________________
# block4_1_BN (BatchNormalization (None, 28, 28, 128)  512         block4_1_Conv[0][0]
# __________________________________________________________________________________________________
# block4_2_Conv (Conv2D)          (None, 28, 28, 128)  147584      block4_1_BN[0][0]
# __________________________________________________________________________________________________
# short_block4_Conv (Conv2D)      (None, 28, 28, 128)  73856       add_3[0][0]
# __________________________________________________________________________________________________
# block4_2_BN (BatchNormalization (None, 28, 28, 128)  512         block4_2_Conv[0][0]
# __________________________________________________________________________________________________
# short_block4_BN (BatchNormaliza (None, 28, 28, 128)  512         short_block4_Conv[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 128)  0           block4_2_BN[0][0]
#                                                                  short_block4_BN[0][0]
# __________________________________________________________________________________________________
# block5_1_Conv (Conv2D)          (None, 28, 28, 128)  147584      add_4[0][0]
# __________________________________________________________________________________________________
# block5_1_BN (BatchNormalization (None, 28, 28, 128)  512         block5_1_Conv[0][0]
# __________________________________________________________________________________________________
# block5_2_Conv (Conv2D)          (None, 28, 28, 128)  147584      block5_1_BN[0][0]
# __________________________________________________________________________________________________
# block5_2_BN (BatchNormalization (None, 28, 28, 128)  512         block5_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 128)  0           block5_2_BN[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block6_1_Conv (Conv2D)          (None, 28, 28, 128)  147584      add_5[0][0]
# __________________________________________________________________________________________________
# block6_1_BN (BatchNormalization (None, 28, 28, 128)  512         block6_1_Conv[0][0]
# __________________________________________________________________________________________________
# block6_2_Conv (Conv2D)          (None, 28, 28, 128)  147584      block6_1_BN[0][0]
# __________________________________________________________________________________________________
# block6_2_BN (BatchNormalization (None, 28, 28, 128)  512         block6_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 128)  0           block6_2_BN[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block7_1_Conv (Conv2D)          (None, 28, 28, 128)  147584      add_6[0][0]
# __________________________________________________________________________________________________
# block7_1_BN (BatchNormalization (None, 28, 28, 128)  512         block7_1_Conv[0][0]
# __________________________________________________________________________________________________
# block7_2_Conv (Conv2D)          (None, 28, 28, 128)  147584      block7_1_BN[0][0]
# __________________________________________________________________________________________________
# block7_2_BN (BatchNormalization (None, 28, 28, 128)  512         block7_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 128)  0           block7_2_BN[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block8_1_Conv (Conv2D)          (None, 14, 14, 256)  295168      add_7[0][0]
# __________________________________________________________________________________________________
# block8_1_BN (BatchNormalization (None, 14, 14, 256)  1024        block8_1_Conv[0][0]
# __________________________________________________________________________________________________
# block8_2_Conv (Conv2D)          (None, 14, 14, 256)  590080      block8_1_BN[0][0]
# __________________________________________________________________________________________________
# short_block8_Conv (Conv2D)      (None, 14, 14, 256)  295168      add_7[0][0]
# __________________________________________________________________________________________________
# block8_2_BN (BatchNormalization (None, 14, 14, 256)  1024        block8_2_Conv[0][0]
# __________________________________________________________________________________________________
# short_block8_BN (BatchNormaliza (None, 14, 14, 256)  1024        short_block8_Conv[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 256)  0           block8_2_BN[0][0]
#                                                                  short_block8_BN[0][0]
# __________________________________________________________________________________________________
# block9_1_Conv (Conv2D)          (None, 14, 14, 256)  590080      add_8[0][0]
# __________________________________________________________________________________________________
# block9_1_BN (BatchNormalization (None, 14, 14, 256)  1024        block9_1_Conv[0][0]
# __________________________________________________________________________________________________
# block9_2_Conv (Conv2D)          (None, 14, 14, 256)  590080      block9_1_BN[0][0]
# __________________________________________________________________________________________________
# block9_2_BN (BatchNormalization (None, 14, 14, 256)  1024        block9_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 256)  0           block9_2_BN[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block10_1_Conv (Conv2D)         (None, 14, 14, 256)  590080      add_9[0][0]
# __________________________________________________________________________________________________
# block10_1_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block10_1_Conv[0][0]
# __________________________________________________________________________________________________
# block10_2_Conv (Conv2D)         (None, 14, 14, 256)  590080      block10_1_BN[0][0]
# __________________________________________________________________________________________________
# block10_2_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block10_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 256)  0           block10_2_BN[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block11_1_Conv (Conv2D)         (None, 14, 14, 256)  590080      add_10[0][0]
# __________________________________________________________________________________________________
# block11_1_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block11_1_Conv[0][0]
# __________________________________________________________________________________________________
# block11_2_Conv (Conv2D)         (None, 14, 14, 256)  590080      block11_1_BN[0][0]
# __________________________________________________________________________________________________
# block11_2_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block11_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 256)  0           block11_2_BN[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block12_1_Conv (Conv2D)         (None, 14, 14, 256)  590080      add_11[0][0]
# __________________________________________________________________________________________________
# block12_1_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block12_1_Conv[0][0]
# __________________________________________________________________________________________________
# block12_2_Conv (Conv2D)         (None, 14, 14, 256)  590080      block12_1_BN[0][0]
# __________________________________________________________________________________________________
# block12_2_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block12_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 256)  0           block12_2_BN[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# block13_1_Conv (Conv2D)         (None, 14, 14, 256)  590080      add_12[0][0]
# __________________________________________________________________________________________________
# block13_1_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block13_1_Conv[0][0]
# __________________________________________________________________________________________________
# block13_2_Conv (Conv2D)         (None, 14, 14, 256)  590080      block13_1_BN[0][0]
# __________________________________________________________________________________________________
# block13_2_BN (BatchNormalizatio (None, 14, 14, 256)  1024        block13_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 256)  0           block13_2_BN[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# block14_1_Conv (Conv2D)         (None, 7, 7, 512)    1180160     add_13[0][0]
# __________________________________________________________________________________________________
# block14_1_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block14_1_Conv[0][0]
# __________________________________________________________________________________________________
# block14_2_Conv (Conv2D)         (None, 7, 7, 512)    2359808     block14_1_BN[0][0]
# __________________________________________________________________________________________________
# short_block14_Conv (Conv2D)     (None, 7, 7, 512)    1180160     add_13[0][0]
# __________________________________________________________________________________________________
# block14_2_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block14_2_Conv[0][0]
# __________________________________________________________________________________________________
# short_block14_BN (BatchNormaliz (None, 7, 7, 512)    2048        short_block14_Conv[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 512)    0           block14_2_BN[0][0]
#                                                                  short_block14_BN[0][0]
# __________________________________________________________________________________________________
# block15_1_Conv (Conv2D)         (None, 7, 7, 512)    2359808     add_14[0][0]
# __________________________________________________________________________________________________
# block15_1_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block15_1_Conv[0][0]
# __________________________________________________________________________________________________
# block15_2_Conv (Conv2D)         (None, 7, 7, 512)    2359808     block15_1_BN[0][0]
# __________________________________________________________________________________________________
# block15_2_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block15_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 512)    0           block15_2_BN[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# block16_1_Conv (Conv2D)         (None, 7, 7, 512)    2359808     add_15[0][0]
# __________________________________________________________________________________________________
# block16_1_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block16_1_Conv[0][0]
# __________________________________________________________________________________________________
# block16_2_Conv (Conv2D)         (None, 7, 7, 512)    2359808     block16_1_BN[0][0]
# __________________________________________________________________________________________________
# block16_2_BN (BatchNormalizatio (None, 7, 7, 512)    2048        block16_2_Conv[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 512)    0           block16_2_BN[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# AveragePooling2D1 (AveragePooli (None, 1, 1, 512)    0           add_16[0][0]
# __________________________________________________________________________________________________
# Flat1 (Flatten)                 (None, 512)          0           AveragePooling2D1[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 1000)         513000      Flat1[0][0]
# ==================================================================================================
# Total params: 23,199,464
# Trainable params: 23,182,440
# Non-trainable params: 17,024
# __________________________________________________________________________________________________
