# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# - noise：控制属于同一个圈的样本点附加的漂移程度
# - factor：控制内外圈的接近程度，越大越接近，上限为1

# %%
X,y = datasets.make_circles(n_samples=10000, shuffle=True, noise=0.04, random_state=None, factor=0.8)

df = pd.DataFrame(data = X, columns = ['a', 'b'])
df['label'] = y

df.head()
# Out:
#           a         b  label
# 0 -0.322978 -0.932847      0
# 1  0.357968  0.902416      0
# 2 -0.917836 -0.411150      0
# 3 -0.211802 -0.821691      1
# 4 -0.417019 -0.712433      1

# %%
plt.figure(figsize = (8, 8))
plt.scatter(df.a, df.b, c = df.label, s=8)
