# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
X,y = datasets.make_moons(n_samples=1000, shuffle=True, noise=0.05, random_state=None)

df = pd.DataFrame(data = X, columns = ['a', 'b'])
df['label'] = y
df.head()
# Out:
#           a         b  label
# 0  2.000392  0.114566      1
# 1  0.076318  0.041093      1
# 2  0.214802 -0.097059      1
# 3 -0.786814  0.672263      0
# 4  0.588439  0.754957      0

# %%
plt.figure(figsize = (12, 8))
plt.scatter(df.a, df.b, c = df.label)
