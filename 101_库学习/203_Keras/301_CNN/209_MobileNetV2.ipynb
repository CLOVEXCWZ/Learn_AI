# %%
import keras  
from keras.layers import Input, Conv2D,GlobalAveragePooling2D, Dense, BatchNormalization, Activation
from keras.models import Model
from keras.layers import DepthwiseConv2D

# %%
gb_depthwise_no = 0

def depthwise_separable(x, feature_maps, stride=1, depthwise_no=None):  
    global gb_depthwise_no
    if depthwise_no is None: 
        gb_depthwise_no += 1
        depthwise_no = gb_depthwise_no  
    depthwise_name="depthwise"+str(depthwise_no)
    
    x = DepthwiseConv2D((3,3),strides=(stride, stride), padding='same', name=depthwise_name+"conv1")(x) 
    x = BatchNormalization()(x) 
    x = Activation('relu')(x) 
    x = Conv2D(int(feature_maps), (1,1), strides=(1,1), padding='same', name=depthwise_name+"conv2")(x) 
    x = BatchNormalization()(x) 
    x = Activation('relu')(x)
    return x

# %%
def MobileNet(img_input, shallow=False, classes=10): 
     
    x = Conv2D(int(32), (3,3), strides=(2,2), padding='same', name="conv1")(img_input) 
    x = BatchNormalization()(x) 
    x = Activation('relu')(x)

    x = depthwise_separable(x,feature_maps=64,  stride=1, depthwise_no=1)
    x = depthwise_separable(x,feature_maps=128, stride=2, depthwise_no=2)
    x = depthwise_separable(x,feature_maps=128, stride=1, depthwise_no=3)
    x = depthwise_separable(x,feature_maps=256, stride=2, depthwise_no=4)
    x = depthwise_separable(x,feature_maps=256, stride=1, depthwise_no=5)
    x = depthwise_separable(x,feature_maps=5112, stride=2, depthwise_no=6) 
    
    if not shallow:
        for i in range(5):
            x = depthwise_separable(x,feature_maps=5112, stride=1, depthwise_no=7+i)  
    depthwise_no = 7+ (5 if not shallow else 0)
    
    x = depthwise_separable(x,feature_maps=1024, stride=2, depthwise_no=depthwise_no+1)  
    x = depthwise_separable(x,feature_maps=1024, stride=1, depthwise_no=depthwise_no+2)  
     
    x = GlobalAveragePooling2D()(x)
    out = Dense(classes, activation='softmax', name="Dense1")(x)
    return out
img_input=Input(shape=(32,32,3), name="Input")
output = MobileNet(img_input)
model=Model(img_input,output)
model.summary()

# 把模型保存为图片
from keras.utils import plot_model
plot_model(model,to_file='model_png/209MobileNetV2.png', show_layer_names=True, show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 32, 32, 3)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 16, 16, 32)        896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# depthwise1conv1 (DepthwiseCo (None, 16, 16, 32)        320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# depthwise1conv2 (Conv2D)     (None, 16, 16, 64)        2112
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# depthwise2conv1 (DepthwiseCo (None, 8, 8, 64)          640
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 64)          0
# _________________________________________________________________
# depthwise2conv2 (Conv2D)     (None, 8, 8, 128)         8320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# depthwise3conv1 (DepthwiseCo (None, 8, 8, 128)         1280
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# depthwise3conv2 (Conv2D)     (None, 8, 8, 128)         16512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# depthwise4conv1 (DepthwiseCo (None, 4, 4, 128)         1280
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# activation_11 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# depthwise4conv2 (Conv2D)     (None, 4, 4, 256)         33024
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_12 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# depthwise5conv1 (DepthwiseCo (None, 4, 4, 256)         2560
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# depthwise5conv2 (Conv2D)     (None, 4, 4, 256)         65792
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# depthwise6conv1 (DepthwiseCo (None, 2, 2, 256)         2560
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_15 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# depthwise6conv2 (Conv2D)     (None, 2, 2, 5112)        1313784
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_16 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise7conv1 (DepthwiseCo (None, 2, 2, 5112)        51120
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_17 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise7conv2 (Conv2D)     (None, 2, 2, 5112)        26137656
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_18 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise8conv1 (DepthwiseCo (None, 2, 2, 5112)        51120
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_19 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise8conv2 (Conv2D)     (None, 2, 2, 5112)        26137656
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_20 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise9conv1 (DepthwiseCo (None, 2, 2, 5112)        51120
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_21 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise9conv2 (Conv2D)     (None, 2, 2, 5112)        26137656
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_22 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise10conv1 (DepthwiseC (None, 2, 2, 5112)        51120
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_23 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise10conv2 (Conv2D)    (None, 2, 2, 5112)        26137656
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_24 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise11conv1 (DepthwiseC (None, 2, 2, 5112)        51120
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_25 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise11conv2 (Conv2D)    (None, 2, 2, 5112)        26137656
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 2, 2, 5112)        20448
# _________________________________________________________________
# activation_26 (Activation)   (None, 2, 2, 5112)        0
# _________________________________________________________________
# depthwise13conv1 (DepthwiseC (None, 1, 1, 5112)        51120
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 1, 1, 5112)        20448
# _________________________________________________________________
# activation_27 (Activation)   (None, 1, 1, 5112)        0
# _________________________________________________________________
# depthwise13conv2 (Conv2D)    (None, 1, 1, 1024)        5235712
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# activation_28 (Activation)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# depthwise14conv1 (DepthwiseC (None, 1, 1, 1024)        10240
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# activation_29 (Activation)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# depthwise14conv2 (Conv2D)    (None, 1, 1, 1024)        1049600
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 1, 1, 1024)        4096
# _________________________________________________________________
# activation_30 (Activation)   (None, 1, 1, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 10)                10250
# =================================================================
# Total params: 139,014,458
# Trainable params: 138,882,170
# Non-trainable params: 132,288
# _________________________________________________________________
