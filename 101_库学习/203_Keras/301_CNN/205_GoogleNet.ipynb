# %%
#coding=utf-8
from keras.models import Model
from keras.layers import Input,Dense,Dropout,BatchNormalization,Conv2D,MaxPooling2D,AveragePooling2D,concatenate
from keras.layers.convolutional import Conv2D,MaxPooling2D,AveragePooling2D
import numpy as np
seed = 7
np.random.seed(seed)

# %%
num_BN = 1
def Conv2d_BN(x, nb_filter,kernel_size, padding='same',strides=(1,1),name=None):
    if name is None:
        name = str(num_BN)
        num_BN += 1  
        
    x = Conv2D(nb_filter,kernel_size,padding=padding,strides=strides,activation='relu',name=name + "_Conv")(x)
    x = BatchNormalization(axis=3,name=name + "_NB")(x)
    return x

# %%
def Inception(x, nb_filter, Inception_no=None):  
    
    branch1x1 = Conv2d_BN(x,nb_filter,kernel_size=(1,1), padding='same',strides=(1,1), name="Inception_%d_branch1x1_1"%(Inception_no))
 
    branch3x3 = Conv2d_BN(x,nb_filter,kernel_size=(1,1), padding='same',strides=(1,1),name="Inception_%d_branch1x1_2"%(Inception_no))
    branch3x3 = Conv2d_BN(branch3x3,nb_filter,kernel_size=(3,3), padding='same',strides=(1,1),name="Inception_%d_branch3x3_1"%(Inception_no))
 
    branch5x5 = Conv2d_BN(x,nb_filter,kernel_size=(3,3), padding='same',strides=(1,1),name="Inception_%d_branch3x3_2"%(Inception_no))
    branch5x5 = Conv2d_BN(branch5x5,nb_filter,kernel_size=(3,3), padding='same',strides=(1,1),name="Inception_%d_branch3x3_3"%(Inception_no))
 
    Inception_name = "Inception_no%d"%(Inception_no) 
    branchpool = MaxPooling2D(pool_size=(3,3),strides=(1,1),padding='same', name=Inception_name+"_pool")(x)
    branchpool = Conv2d_BN(branchpool,nb_filter,kernel_size=(1,1),padding='same',strides=(1,1),name="Inception_%d_branch1x1_3"%(Inception_no))
     
    x = concatenate([branch1x1, branch3x3, branch5x5, branchpool],axis=3, name=Inception_name+"_Concat")
    return x

# %%
 inpt = Input(shape=(224,224,3), name="Input")
#padding = 'same'，填充为(步长-1）/2,还可以用ZeroPadding2D((3,3))
x = Conv2d_BN(inpt,64,(7,7),strides=(2,2),padding='same', name="NB1")
 
x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same', name="pool1")(x)
x = Conv2d_BN(x,192,(3,3),strides=(1,1),padding='same', name="NB2")
 
x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same', name="pool2")(x)
x = Inception(x,64, Inception_no=1)#256
x = Inception(x,120, Inception_no=2)#480
 
x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same', name="pool3")(x)
x = Inception(x,128, Inception_no=3)#512
x = Inception(x,128, Inception_no=4)
x = Inception(x,128, Inception_no=5)
x = Inception(x,132, Inception_no=6)#528
x = Inception(x,208, Inception_no=7)#832
 
x = MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same', name="pool4")(x)
x = Inception(x,208, Inception_no=8)
x = Inception(x,256, Inception_no=9)#1024
 
x = AveragePooling2D(pool_size=(7,7),strides=(7,7),padding='same')(x)
x = Dropout(0.4, name="Dropout1")(x)
x = Dense(1000,activation='relu', name="Dense1")(x)
x = Dense(1000,activation='softmax', name="Dense2")(x)
model = Model(inpt,x,name='inception')
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])
model.summary()

# 把模型保存为图片
from keras.utils import plot_model
plot_model(model,to_file='model_png/205GoogleNet.png', show_layer_names=True, show_shapes=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# NB1_Conv (Conv2D)               (None, 112, 112, 64) 9472        Input[0][0]
# __________________________________________________________________________________________________
# NB1_NB (BatchNormalization)     (None, 112, 112, 64) 256         NB1_Conv[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           NB1_NB[0][0]
# __________________________________________________________________________________________________
# NB2_Conv (Conv2D)               (None, 56, 56, 192)  110784      pool1[0][0]
# __________________________________________________________________________________________________
# NB2_NB (BatchNormalization)     (None, 56, 56, 192)  768         NB2_Conv[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 28, 28, 192)  0           NB2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch1x1_2_Conv (C (None, 28, 28, 64)   12352       pool2[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch3x3_2_Conv (C (None, 28, 28, 64)   110656      pool2[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch1x1_2_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_1_branch3x3_2_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no1_pool (MaxPooling2 (None, 28, 28, 192)  0           pool2[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch1x1_1_Conv (C (None, 28, 28, 64)   12352       pool2[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch3x3_1_Conv (C (None, 28, 28, 64)   36928       Inception_1_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch3x3_3_Conv (C (None, 28, 28, 64)   36928       Inception_1_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch1x1_3_Conv (C (None, 28, 28, 64)   12352       Inception_no1_pool[0][0]
# __________________________________________________________________________________________________
# Inception_1_branch1x1_1_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_1_branch3x3_1_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_1_branch3x3_3_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_1_branch1x1_3_NB (Bat (None, 28, 28, 64)   256         Inception_1_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no1_Concat (Concatena (None, 28, 28, 256)  0           Inception_1_branch1x1_1_NB[0][0]
#                                                                  Inception_1_branch3x3_1_NB[0][0]
#                                                                  Inception_1_branch3x3_3_NB[0][0]
#                                                                  Inception_1_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch1x1_2_Conv (C (None, 28, 28, 120)  30840       Inception_no1_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch3x3_2_Conv (C (None, 28, 28, 120)  276600      Inception_no1_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch1x1_2_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_2_branch3x3_2_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no2_pool (MaxPooling2 (None, 28, 28, 256)  0           Inception_no1_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch1x1_1_Conv (C (None, 28, 28, 120)  30840       Inception_no1_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch3x3_1_Conv (C (None, 28, 28, 120)  129720      Inception_2_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch3x3_3_Conv (C (None, 28, 28, 120)  129720      Inception_2_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch1x1_3_Conv (C (None, 28, 28, 120)  30840       Inception_no2_pool[0][0]
# __________________________________________________________________________________________________
# Inception_2_branch1x1_1_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_2_branch3x3_1_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_2_branch3x3_3_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_2_branch1x1_3_NB (Bat (None, 28, 28, 120)  480         Inception_2_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no2_Concat (Concatena (None, 28, 28, 480)  0           Inception_2_branch1x1_1_NB[0][0]
#                                                                  Inception_2_branch3x3_1_NB[0][0]
#                                                                  Inception_2_branch3x3_3_NB[0][0]
#                                                                  Inception_2_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 14, 14, 480)  0           Inception_no2_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch1x1_2_Conv (C (None, 14, 14, 128)  61568       pool3[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch3x3_2_Conv (C (None, 14, 14, 128)  553088      pool3[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch1x1_2_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_3_branch3x3_2_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no3_pool (MaxPooling2 (None, 14, 14, 480)  0           pool3[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch1x1_1_Conv (C (None, 14, 14, 128)  61568       pool3[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch3x3_1_Conv (C (None, 14, 14, 128)  147584      Inception_3_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch3x3_3_Conv (C (None, 14, 14, 128)  147584      Inception_3_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch1x1_3_Conv (C (None, 14, 14, 128)  61568       Inception_no3_pool[0][0]
# __________________________________________________________________________________________________
# Inception_3_branch1x1_1_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_3_branch3x3_1_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_3_branch3x3_3_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_3_branch1x1_3_NB (Bat (None, 14, 14, 128)  512         Inception_3_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no3_Concat (Concatena (None, 14, 14, 512)  0           Inception_3_branch1x1_1_NB[0][0]
#                                                                  Inception_3_branch3x3_1_NB[0][0]
#                                                                  Inception_3_branch3x3_3_NB[0][0]
#                                                                  Inception_3_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch1x1_2_Conv (C (None, 14, 14, 128)  65664       Inception_no3_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch3x3_2_Conv (C (None, 14, 14, 128)  589952      Inception_no3_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch1x1_2_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_4_branch3x3_2_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no4_pool (MaxPooling2 (None, 14, 14, 512)  0           Inception_no3_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch1x1_1_Conv (C (None, 14, 14, 128)  65664       Inception_no3_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch3x3_1_Conv (C (None, 14, 14, 128)  147584      Inception_4_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch3x3_3_Conv (C (None, 14, 14, 128)  147584      Inception_4_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch1x1_3_Conv (C (None, 14, 14, 128)  65664       Inception_no4_pool[0][0]
# __________________________________________________________________________________________________
# Inception_4_branch1x1_1_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_4_branch3x3_1_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_4_branch3x3_3_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_4_branch1x1_3_NB (Bat (None, 14, 14, 128)  512         Inception_4_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no4_Concat (Concatena (None, 14, 14, 512)  0           Inception_4_branch1x1_1_NB[0][0]
#                                                                  Inception_4_branch3x3_1_NB[0][0]
#                                                                  Inception_4_branch3x3_3_NB[0][0]
#                                                                  Inception_4_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch1x1_2_Conv (C (None, 14, 14, 128)  65664       Inception_no4_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch3x3_2_Conv (C (None, 14, 14, 128)  589952      Inception_no4_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch1x1_2_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_5_branch3x3_2_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no5_pool (MaxPooling2 (None, 14, 14, 512)  0           Inception_no4_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch1x1_1_Conv (C (None, 14, 14, 128)  65664       Inception_no4_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch3x3_1_Conv (C (None, 14, 14, 128)  147584      Inception_5_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch3x3_3_Conv (C (None, 14, 14, 128)  147584      Inception_5_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch1x1_3_Conv (C (None, 14, 14, 128)  65664       Inception_no5_pool[0][0]
# __________________________________________________________________________________________________
# Inception_5_branch1x1_1_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_5_branch3x3_1_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_5_branch3x3_3_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_5_branch1x1_3_NB (Bat (None, 14, 14, 128)  512         Inception_5_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no5_Concat (Concatena (None, 14, 14, 512)  0           Inception_5_branch1x1_1_NB[0][0]
#                                                                  Inception_5_branch3x3_1_NB[0][0]
#                                                                  Inception_5_branch3x3_3_NB[0][0]
#                                                                  Inception_5_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch1x1_2_Conv (C (None, 14, 14, 132)  67716       Inception_no5_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch3x3_2_Conv (C (None, 14, 14, 132)  608388      Inception_no5_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch1x1_2_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_6_branch3x3_2_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no6_pool (MaxPooling2 (None, 14, 14, 512)  0           Inception_no5_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch1x1_1_Conv (C (None, 14, 14, 132)  67716       Inception_no5_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch3x3_1_Conv (C (None, 14, 14, 132)  156948      Inception_6_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch3x3_3_Conv (C (None, 14, 14, 132)  156948      Inception_6_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch1x1_3_Conv (C (None, 14, 14, 132)  67716       Inception_no6_pool[0][0]
# __________________________________________________________________________________________________
# Inception_6_branch1x1_1_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_6_branch3x3_1_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_6_branch3x3_3_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_6_branch1x1_3_NB (Bat (None, 14, 14, 132)  528         Inception_6_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no6_Concat (Concatena (None, 14, 14, 528)  0           Inception_6_branch1x1_1_NB[0][0]
#                                                                  Inception_6_branch3x3_1_NB[0][0]
#                                                                  Inception_6_branch3x3_3_NB[0][0]
#                                                                  Inception_6_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch1x1_2_Conv (C (None, 14, 14, 208)  110032      Inception_no6_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch3x3_2_Conv (C (None, 14, 14, 208)  988624      Inception_no6_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch1x1_2_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_7_branch3x3_2_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no7_pool (MaxPooling2 (None, 14, 14, 528)  0           Inception_no6_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch1x1_1_Conv (C (None, 14, 14, 208)  110032      Inception_no6_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch3x3_1_Conv (C (None, 14, 14, 208)  389584      Inception_7_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch3x3_3_Conv (C (None, 14, 14, 208)  389584      Inception_7_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch1x1_3_Conv (C (None, 14, 14, 208)  110032      Inception_no7_pool[0][0]
# __________________________________________________________________________________________________
# Inception_7_branch1x1_1_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_7_branch3x3_1_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_7_branch3x3_3_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_7_branch1x1_3_NB (Bat (None, 14, 14, 208)  832         Inception_7_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no7_Concat (Concatena (None, 14, 14, 832)  0           Inception_7_branch1x1_1_NB[0][0]
#                                                                  Inception_7_branch3x3_1_NB[0][0]
#                                                                  Inception_7_branch3x3_3_NB[0][0]
#                                                                  Inception_7_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 7, 7, 832)    0           Inception_no7_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch1x1_2_Conv (C (None, 7, 7, 208)    173264      pool4[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch3x3_2_Conv (C (None, 7, 7, 208)    1557712     pool4[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch1x1_2_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_8_branch3x3_2_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no8_pool (MaxPooling2 (None, 7, 7, 832)    0           pool4[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch1x1_1_Conv (C (None, 7, 7, 208)    173264      pool4[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch3x3_1_Conv (C (None, 7, 7, 208)    389584      Inception_8_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch3x3_3_Conv (C (None, 7, 7, 208)    389584      Inception_8_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch1x1_3_Conv (C (None, 7, 7, 208)    173264      Inception_no8_pool[0][0]
# __________________________________________________________________________________________________
# Inception_8_branch1x1_1_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_8_branch3x3_1_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_8_branch3x3_3_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_8_branch1x1_3_NB (Bat (None, 7, 7, 208)    832         Inception_8_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no8_Concat (Concatena (None, 7, 7, 832)    0           Inception_8_branch1x1_1_NB[0][0]
#                                                                  Inception_8_branch3x3_1_NB[0][0]
#                                                                  Inception_8_branch3x3_3_NB[0][0]
#                                                                  Inception_8_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch1x1_2_Conv (C (None, 7, 7, 256)    213248      Inception_no8_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch3x3_2_Conv (C (None, 7, 7, 256)    1917184     Inception_no8_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch1x1_2_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch1x1_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_9_branch3x3_2_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch3x3_2_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no9_pool (MaxPooling2 (None, 7, 7, 832)    0           Inception_no8_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch1x1_1_Conv (C (None, 7, 7, 256)    213248      Inception_no8_Concat[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch3x3_1_Conv (C (None, 7, 7, 256)    590080      Inception_9_branch1x1_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch3x3_3_Conv (C (None, 7, 7, 256)    590080      Inception_9_branch3x3_2_NB[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch1x1_3_Conv (C (None, 7, 7, 256)    213248      Inception_no9_pool[0][0]
# __________________________________________________________________________________________________
# Inception_9_branch1x1_1_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch1x1_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_9_branch3x3_1_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch3x3_1_Conv[0][0
# __________________________________________________________________________________________________
# Inception_9_branch3x3_3_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch3x3_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_9_branch1x1_3_NB (Bat (None, 7, 7, 256)    1024        Inception_9_branch1x1_3_Conv[0][0
# __________________________________________________________________________________________________
# Inception_no9_Concat (Concatena (None, 7, 7, 1024)   0           Inception_9_branch1x1_1_NB[0][0]
#                                                                  Inception_9_branch3x3_1_NB[0][0]
#                                                                  Inception_9_branch3x3_3_NB[0][0]
#                                                                  Inception_9_branch1x1_3_NB[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 1024)   0           Inception_no9_Concat[0][0]
# __________________________________________________________________________________________________
# Dropout1 (Dropout)              (None, 1, 1, 1024)   0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 1, 1, 1000)   1025000     Dropout1[0][0]
# __________________________________________________________________________________________________
# Dense2 (Dense)                  (None, 1, 1, 1000)   1001000     Dense1[0][0]
# ==================================================================================================
# Total params: 16,044,600
# Trainable params: 16,027,624
# Non-trainable params: 16,976
# __________________________________________________________________________________________________
